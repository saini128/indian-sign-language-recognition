# %%
import cv2
import numpy as np
import mediapipe as mp
import tensorflow as tf
from tensorflow import keras
from keras.models import load_model
from keras import layers
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
mp_holistic = mp.solutions.holistic 
mp_drawing = mp.solutions.drawing_utils 

def draw_styled_landmarks(image, results):
    
    
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             ) 
    
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
    image.flags.writeable = False                  
    results = model.process(image)                 
    image.flags.writeable = True                   
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) 
    return image, results

# %%
def initialize_words():
    return ["good", "knock", "black", "lakh", "my"]


def capture_frames(word, num_samples=20):
    cap = cv2.VideoCapture(0)
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands()

    frames = []
    labels = []

    print(f"Capturing {num_samples} frames for '{word}'... Press 'k' to capture a frame.")

    with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:    
        while len(frames) < num_samples:
            ret, frame = cap.read()
            if not ret:
                break

            
            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            
            results = hands.process(rgb_frame)
            landmarks = results.multi_hand_landmarks

            if landmarks:
                
                hand_landmarks = landmarks[0].landmark
                landmarks_flat = [coord for landmark in hand_landmarks for coord in (landmark.x, landmark.y, landmark.z)]

                
                image, results = mediapipe_detection(frame, holistic)
                draw_styled_landmarks(image, results)
                cv2.imshow('OpenCV Feed', image)
                

                
                key = cv2.waitKey(1)
                if key & 0xFF == ord('k'):
                    frames.append(landmarks_flat)
                    labels.append(word)
                    print(f"Captured {len(frames)} frames")

    cap.release()
    cv2.destroyAllWindows()

    return np.array(frames), np.array(labels)


def train_model(X_train, y_train):
    model = keras.Sequential([
        layers.Input(shape=(63,)),  
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(5, activation='softmax')  
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    model.fit(X_train, y_train, epochs=100, batch_size=32)

    return model


def test_model(model):
    cap = cv2.VideoCapture(0)
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands()

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        
        results = hands.process(rgb_frame)
        landmarks = results.multi_hand_landmarks

        if landmarks:
            
            hand_landmarks = landmarks[0].landmark
            landmarks_flat = [coord for landmark in hand_landmarks for coord in (landmark.x, landmark.y, landmark.z)]

            
            prediction = model.predict(np.array([landmarks_flat]))
            predicted_class = np.argmax(prediction)

            
            cv2.putText(frame, initialize_words()[predicted_class], (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        
        cv2.imshow("Hand Gesture Recognition", frame)

        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
words = initialize_words()
X_train, y_train = [], []

for word in words:
    frames, labels = capture_frames(word)
    X_train.extend(frames)
    y_train.extend(labels)

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)

X_train = np.array(X_train)
y_train = np.karray(y_train)
# Out:
# Capturing 20 frames for 'good'... Press 'k' to capture a frame.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\indian-sign-language\trial2\main2.ipynb Cell 4 line 5
#       <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> X_train, y_train = [], []
#       <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> for word in words:
# ----> <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a>     frames, labels = capture_frames(word)
#       <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=5'>6</a>     X_train.extend(frames)
#       <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=6'>7</a>     y_train.extend(labels)
#
# d:\indian-sign-language\trial2\main2.ipynb Cell 4 line 2
#      <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=22'>23</a> rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=24'>25</a> # Process the frame using MediaPipe
# ---> <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=25'>26</a> results = hands.process(rgb_frame)
#      <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=26'>27</a> landmarks = results.multi_hand_landmarks
#      <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=28'>29</a> if landmarks:
#      <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main2.ipynb#W4sZmlsZQ%3D%3D?line=29'>30</a>     # Extract hand landmarks
#
# File c:\Users\Singh\anaconda3\Lib\site-packages\mediapipe\python\solutions\hands.py:153, in Hands.process(self, image)
#     132 def process(self, image: np.ndarray) -> NamedTuple:
#     133   """Processes an RGB image and returns the hand landmarks and handedness of each detected hand.
#     134
#     135   Args:
#    (...)
#     150          right hand) of the detected hand.
#     151   """
# --> 153   return super().process(input_data={'image': image})
#
# File c:\Users\Singh\anaconda3\Lib\site-packages\mediapipe\python\solution_base.py:372, in SolutionBase.process(self, input_data)
#     366   else:
#     367     self._graph.add_packet_to_input_stream(
#     368         stream=stream_name,
#     369         packet=self._make_packet(input_stream_type,
#     370                                  data).at(self._simulated_timestamp))
# --> 372 self._graph.wait_until_idle()
#     373 # Create a NamedTuple object where the field names are mapping to the graph
#     374 # output stream names.
#     375 solution_outputs = collections.namedtuple(
#     376     'SolutionOutputs', self._output_stream_type_info.keys())
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model = train_model(X_train, y_train)

print("Model training complete. Testing the model in real-time...")
# Out:
# Epoch 1/100
# 4/4 [==============================] - 2s 5ms/step - loss: 1.6202 - accuracy: 0.0800
# Epoch 2/100
# 4/4 [==============================] - 0s 7ms/step - loss: 1.5405 - accuracy: 0.2000
# Epoch 3/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.5041 - accuracy: 0.2000
# Epoch 4/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4664 - accuracy: 0.2000
# Epoch 5/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.4386 - accuracy: 0.2000
# Epoch 6/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.4088 - accuracy: 0.2000
# Epoch 7/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3743 - accuracy: 0.2500
# Epoch 8/100
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3492 - accuracy: 0.3100
# Epoch 9/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2990 - accuracy: 0.4000
# Epoch 10/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2534 - accuracy: 0.6200
# Epoch 11/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2070 - accuracy: 0.7900
# Epoch 12/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1666 - accuracy: 0.7700
# Epoch 13/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1147 - accuracy: 0.9000
# Epoch 14/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0612 - accuracy: 0.7800
# Epoch 15/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0088 - accuracy: 0.8000
# Epoch 16/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9598 - accuracy: 0.8000
# Epoch 17/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9075 - accuracy: 0.7900
# Epoch 18/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8739 - accuracy: 0.6200
# Epoch 19/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8250 - accuracy: 0.7000
# Epoch 20/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7744 - accuracy: 0.8000
# Epoch 21/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7320 - accuracy: 0.8000
# Epoch 22/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6884 - accuracy: 0.8000
# Epoch 23/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6419 - accuracy: 0.8000
# Epoch 24/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6103 - accuracy: 0.8000
# Epoch 25/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5724 - accuracy: 0.8400
# Epoch 26/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5387 - accuracy: 1.0000
# Epoch 27/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5093 - accuracy: 1.0000
# Epoch 28/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4812 - accuracy: 1.0000
# Epoch 29/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4651 - accuracy: 1.0000
# Epoch 30/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4337 - accuracy: 1.0000
# Epoch 31/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4169 - accuracy: 1.0000
# Epoch 32/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3927 - accuracy: 1.0000
# Epoch 33/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3749 - accuracy: 1.0000
# Epoch 34/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3496 - accuracy: 1.0000
# Epoch 35/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3323 - accuracy: 1.0000
# Epoch 36/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3180 - accuracy: 1.0000
# Epoch 37/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2996 - accuracy: 1.0000
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2867 - accuracy: 1.0000
# Epoch 39/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2773 - accuracy: 1.0000
# Epoch 40/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2614 - accuracy: 1.0000
# Epoch 41/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2487 - accuracy: 1.0000
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2401 - accuracy: 1.0000
# Epoch 43/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2283 - accuracy: 1.0000
# Epoch 44/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2147 - accuracy: 1.0000
# Epoch 45/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2016 - accuracy: 1.0000
# Epoch 46/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1933 - accuracy: 1.0000
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1808 - accuracy: 1.0000
# Epoch 48/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1710 - accuracy: 1.0000
# Epoch 49/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1626 - accuracy: 1.0000
# Epoch 50/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1528 - accuracy: 1.0000
# Epoch 51/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1455 - accuracy: 1.0000
# Epoch 52/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1433 - accuracy: 1.0000
# Epoch 53/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1329 - accuracy: 1.0000
# Epoch 54/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1215 - accuracy: 1.0000
# Epoch 55/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1174 - accuracy: 1.0000
# Epoch 56/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1133 - accuracy: 1.0000
# Epoch 57/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1039 - accuracy: 1.0000
# Epoch 58/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0966 - accuracy: 1.0000
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0910 - accuracy: 1.0000
# Epoch 60/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0855 - accuracy: 1.0000
# Epoch 61/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0813 - accuracy: 1.0000
# Epoch 62/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0767 - accuracy: 1.0000
# Epoch 63/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0719 - accuracy: 1.0000
# Epoch 64/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0675 - accuracy: 1.0000
# Epoch 65/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 66/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 67/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 68/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 69/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0497 - accuracy: 1.0000
# Epoch 70/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0469 - accuracy: 1.0000
# Epoch 71/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 72/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0416 - accuracy: 1.0000
# Epoch 73/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0390 - accuracy: 1.0000
# Epoch 74/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 75/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0348 - accuracy: 1.0000
# Epoch 76/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 77/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 78/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 79/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 80/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0271 - accuracy: 1.0000
# Epoch 81/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 82/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 83/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 84/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 85/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 86/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 87/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 88/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 89/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 90/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 91/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 92/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 93/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 95/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 96/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 97/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 99/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 100/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 1.0000
# Model training complete. Testing the model in real-time...

# %%
def test_model(model, min_hand_detection_confidence=0.5):
    cap = cv2.VideoCapture(0)
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(min_detection_confidence=min_hand_detection_confidence)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        
        results = hands.process(rgb_frame)
        landmarks = results.multi_hand_landmarks

        if landmarks:
            
            if results.multi_handedness[0].classification[0].score > min_hand_detection_confidence:
                
                hand_landmarks = landmarks[0].landmark
                landmarks_flat = [coord for landmark in hand_landmarks for coord in (landmark.x, landmark.y, landmark.z)]

                
                prediction = model.predict(np.array([landmarks_flat]))
                predicted_class = np.argmax(prediction)

                
                cv2.putText(frame, initialize_words()[predicted_class], (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        
        cv2.imshow("Hand Gesture Recognition", frame)

        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()


test_model(model, min_hand_detection_confidence=0.8)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
