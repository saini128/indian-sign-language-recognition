# %%
import cv2
import mediapipe as mp
import numpy as np
from tensorflow import keras
from keras import layers
from sklearn.preprocessing import LabelEncoder

# %%
def initialize_words():
    return ["good", "morning", "afternoon", "Hi", "how are you?", "do", "computer","thank you","i",]

def capture_frames(word, num_samples=20):
    cap = cv2.VideoCapture(0)
    mp_holistic = mp.solutions.holistic
    mp_drawing = mp.solutions.drawing_utils
    
    holistic = mp_holistic.Holistic(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5,
    )

    frames = []
    labels = []

    print(f"Capturing {num_samples} frames for '{word}'... Press 'k' to capture a frame.")

    while len(frames) < num_samples:
        ret, frame = cap.read()
        if not ret:
            break

        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        
        results = holistic.process(rgb_frame)
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    
        
        
        
        combined_landmarks = np.concatenate([pose, lh, rh])
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
        cv2.imshow('Hand Gesture Capture', image)

        
        key = cv2.waitKey(1)
        if key & 0xFF == ord('k'):
            frames.append(combined_landmarks)
            labels.append(word)
            print(f"Captured {len(frames)} frames")

    cap.release()
    cv2.destroyAllWindows()

    return np.array(frames), np.array(labels)

def train_model(X_train, y_train):
    model = keras.Sequential([
        layers.Input(shape=(258,)),  
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(9, activation='softmax')  
    ])

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    model.fit(X_train, y_train, epochs=200, batch_size=32)

    
    model.save('hand_gesture_model.h5')

    return model

import cv2
import mediapipe as mp
import numpy as np
from tensorflow import keras

def test_model(model,label_encoder):
    cap = cv2.VideoCapture(0)
    mp_hands = mp.solutions.hands
    mp_pose = mp.solutions.pose
    mp_holistic = mp.solutions.holistic
    mp_drawing = mp.solutions.drawing_utils
    
    holistic = mp_holistic.Holistic(
        min_detection_confidence=0.5,
        min_tracking_confidence=0.5,
    )
    hands = mp_hands.Hands()
    pose = mp_pose.Pose()

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = holistic.process(rgb_frame)
        pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
        lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
        rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    

        input_features = np.concatenate([pose, lh, rh])


        
        prediction = model.predict(np.array([input_features]))
        predicted_class = np.argmax(prediction)
        predicted_word = label_encoder.inverse_transform([predicted_class])[0]

        
        cv2.putText(rgb_frame, predicted_word, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
        mp_drawing.draw_landmarks(rgb_frame, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(rgb_frame, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
        mp_drawing.draw_landmarks(rgb_frame, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
        
        rgb_frame = cv2.cvtColor(rgb_frame, cv2.COLOR_RGB2BGR)
        cv2.imshow("Hand Gesture Recognition", rgb_frame)

        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
words = initialize_words()


all_frames = []
all_labels = []
for word in words:
    frames, labels = capture_frames(word)
    all_frames.append(frames)
    all_labels.append(labels)


X_train = np.concatenate(all_frames)
y_train = np.concatenate(all_labels)
# Out:
# Capturing 20 frames for 'good'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'morning'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'afternoon'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'Hi'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'how are you?'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'do'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'computer'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'thank you'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames
# Capturing 20 frames for 'i'... Press 'k' to capture a frame.
# Captured 1 frames
# Captured 2 frames
# Captured 3 frames
# Captured 4 frames
# Captured 5 frames
# Captured 6 frames
# Captured 7 frames
# Captured 8 frames
# Captured 9 frames
# Captured 10 frames
# Captured 11 frames
# Captured 12 frames
# Captured 13 frames
# Captured 14 frames
# Captured 15 frames
# Captured 16 frames
# Captured 17 frames
# Captured 18 frames
# Captured 19 frames
# Captured 20 frames

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)


# Train the model
model = train_model(X_train, y_train_encoded)
# Out:
# Epoch 1/200
# 6/6 [==============================] - 2s 6ms/step - loss: 2.1688 - accuracy: 0.1778
# Epoch 2/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9666 - accuracy: 0.2556
# Epoch 3/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.7551 - accuracy: 0.3611
# Epoch 4/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.5851 - accuracy: 0.6556
# Epoch 5/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.4444 - accuracy: 0.7889
# Epoch 6/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3184 - accuracy: 0.6722
# Epoch 7/200
# 6/6 [==============================] - 0s 4ms/step - loss: 1.2231 - accuracy: 0.7222
# Epoch 8/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.1210 - accuracy: 0.8278
# Epoch 9/200
# 6/6 [==============================] - 0s 5ms/step - loss: 1.0485 - accuracy: 0.8611
# Epoch 10/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9642 - accuracy: 0.8667
# Epoch 11/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.8762 - accuracy: 0.9278
# Epoch 12/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.8172 - accuracy: 0.8889
# Epoch 13/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7331 - accuracy: 0.9667
# Epoch 14/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.6840 - accuracy: 0.9611
# Epoch 15/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.6271 - accuracy: 0.9722
# Epoch 16/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5830 - accuracy: 0.9722
# Epoch 17/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.5295 - accuracy: 0.9167
# Epoch 18/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4782 - accuracy: 0.9944
# Epoch 19/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.4511 - accuracy: 0.9444
# Epoch 20/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.4027 - accuracy: 0.9889
# Epoch 21/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.3553 - accuracy: 0.9722
# Epoch 22/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.3233 - accuracy: 0.9778
# Epoch 23/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.9944
# Epoch 24/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.2655 - accuracy: 1.0000
# Epoch 25/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2435 - accuracy: 0.9833
# Epoch 26/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2199 - accuracy: 0.9944
# Epoch 27/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.2119 - accuracy: 1.0000
# Epoch 28/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1918 - accuracy: 0.9722
# Epoch 29/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1688 - accuracy: 1.0000
# Epoch 30/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1533 - accuracy: 1.0000
# Epoch 31/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.1453 - accuracy: 0.9944
# Epoch 32/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 1.0000
# Epoch 33/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1231 - accuracy: 1.0000
# Epoch 34/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1148 - accuracy: 1.0000
# Epoch 35/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.1084 - accuracy: 1.0000
# Epoch 36/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 1.0000
# Epoch 37/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 1.0000
# Epoch 38/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0850 - accuracy: 1.0000
# Epoch 39/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 1.0000
# Epoch 40/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 1.0000
# Epoch 41/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0754 - accuracy: 1.0000
# Epoch 42/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0630 - accuracy: 1.0000
# Epoch 43/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 44/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 45/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 1.0000
# Epoch 46/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 47/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0492 - accuracy: 1.0000
# Epoch 48/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 1.0000
# Epoch 49/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 50/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 51/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 52/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 53/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 54/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 1.0000
# Epoch 55/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 1.0000
# Epoch 56/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 57/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 58/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 1.0000
# Epoch 59/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 60/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 61/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 62/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 63/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 64/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 1.0000
# Epoch 65/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 66/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 67/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 68/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 69/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 70/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 71/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 72/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 73/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 74/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 75/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 76/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 77/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 78/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 79/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 80/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 81/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 82/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 83/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 84/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 85/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 86/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 87/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 88/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 89/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 90/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 91/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 92/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 93/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 94/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 95/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 96/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 97/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 98/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 99/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 100/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 101/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 102/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 103/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 104/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 105/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 106/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 107/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 108/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 109/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 110/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 111/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 112/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 113/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 114/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 115/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 116/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 117/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 118/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 119/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 120/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 121/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 122/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 123/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 124/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 125/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 126/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 127/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 128/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 129/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 130/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 131/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 132/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 133/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 134/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 135/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 136/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 137/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 138/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 139/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 140/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 141/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 142/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 143/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 144/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 145/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 146/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 147/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 148/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 149/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 150/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 151/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 152/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 153/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 154/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 155/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 156/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 157/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 158/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 159/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 160/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 161/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 162/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 163/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 164/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 165/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 166/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 167/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 168/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 169/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 170/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 171/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 172/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 173/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 174/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 175/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 176/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 177/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 178/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 179/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 180/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 181/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 182/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 183/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 184/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 185/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 186/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 187/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 188/200
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 189/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 190/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 191/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 192/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 193/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 194/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 195/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 196/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 197/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 198/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 199/200
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 200/200
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# c:\Users\Singh\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
y_train_encoded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\indian-sign-language\trial2\main3.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/indian-sign-language/trial2/main3.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> y_train_encoded
#
# NameError: name 'y_train_encoded' is not defined

# %%
# # Test the model in real-time
# from keras.models import load_model
# model = load_model('hand_gesture_model.h5')
# label_encoder=LabelEncoder()
test_model(model,label_encoder)
# Out:
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
model.save('hand_model.h5')
import joblib

joblib.dump(label_encoder, 'label_encoder.joblib')
# Out:
# ['label_encoder.joblib']
